# %% [markdown]
# ## 이미지 변형(원근)

# %% [markdown]
# ## 사라디꼴 이미지 펼치기

# %%
import cv2
import numpy as np

img = cv2.imread('newspaper.jpg')

width, height = 640, 240 # 가로 크기 640, 세로 크기 640 으로 결과물 출력

src = np.array([[520, 346], [1004, 343], [1120, 573], [467, 575]], dtype=np.float32) # Input 4개 지점
dst = np.array([[0, 0], [width, 0], [width, height], [0, height]], dtype=np.float32) # Output 4개 지점
# 좌상, 우상, 우하, 좌하 (시계 방향 4지점 정의)

matrix = cv2.getPerspectiveTransform(src, dst) # Matrix 얻어옴
result = cv2.warpPerspective(img, matrix, (width, height)) # matrix대로 변환을 함

cv2.imshow('img', img)
cv2.imshow('result', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 회전된 이미지 올바로 세우기

# %%
import cv2
import numpy as np

img = cv2.imread('poker.jpg')

width, height = 521, 772 # 가로 크기 640, 세로 크기 640 으로 결과물 출력

src = np.array([[704, 144], [1130, 415], [719, 997], [274, 693]], dtype=np.float32) # Input 4개 지점
dst = np.array([[0, 0], [width, 0], [width, height], [0, height]], dtype=np.float32) # Output 4개 지점
# 좌상, 우상, 우하, 좌하 (시계 방향 4지점 정의)

matrix = cv2.getPerspectiveTransform(src, dst) # Matrix 얻어옴
result = cv2.warpPerspective(img, matrix, (width, height)) # matrix대로 변환을 함

cv2.imshow('img', img)
cv2.imshow('result', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 미니 프로젝트 : 반자동 문서 스캐너

# %% [markdown]
# ### 마우스 이벤트 등록

# %%
import cv2

img = cv2.imread('poker.jpg')

def mouse_handler(event, x, y, flags, param) :
    if event == cv2.EVENT_LBUTTONDOWN: # 마우스 왼쪽 버튼 누름
        print('왼쪽 버튼 Down')
        print(x, y)
    elif event == cv2.EVENT_LBUTTONUP:
        print("왼쪽 버튼 Up")
    elif event == cv2.EVENT_LBUTTONDBLCLK:
        print("왼쪽 버튼 Double Click")
    elif event == cv2.EVENT_MOUSEMOVE: 
        print("마우스 이동")
    elif event == cv2.EVENT_RBUTTONDOWN:
        print("오른쪽 버튼 DOWN")
        
cv2.namedWindow('img') # img란 이름의 윈도우를 먼저 만들어두는 것. 여기에 마우스 이벤트를 처리하기 위한 핸들러 적용
cv2.setMouseCallback('img', mouse_handler)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# 마우스 이동
# ...

# %% [markdown]
# ## 프로젝트

# %%
import cv2
import numpy as np

point_list = []

src_img = cv2.imread('poker.jpg')

COLOR = (255, 0, 255) #핑크
THICKNESS = 3
drawing = False # 선을 그릴지 여부

def mouse_handler(event, x, y, flags, param) :
    global drawing
    dst_img = src_img.copy()
    if event == cv2.EVENT_LBUTTONDOWN: # 마우스 왼쪽 버튼 누름
        drawing = True # 선을 그리기 시작
        point_list.append((x, y))

    if drawing:
        prev_point = None # 직선의 시작점
        for point in point_list:
            cv2.circle(dst_img, point, 15, COLOR, cv2.FILLED)
            if prev_point:
                cv2.line(dst_img, prev_point, point, COLOR, THICKNESS, cv2.LINE_AA)
            prev_point = point
    next_point = (x, y)
    if len(point_list) == 4:
        show_result()
        next_point = point_list[0] # 첫번째 클릭한 시점
    cv2.line(dst_img, prev_point, next_point, COLOR, THICKNESS, cv2.LINE_AA)

    cv2.imshow('img', dst_img)

def show_result():
    width, height = 530, 710 # 가로 크기 640, 세로 크기 640 으로 결과물 출력

    src = np.float32(point_list)
    dst = np.array([[0, 0], [width, 0], [width, height], [0, height]], dtype=np.float32) # Output 4개 지점
    # 좌상, 우상, 우하, 좌하 (시계 방향 4지점 정의)

    matrix = cv2.getPerspectiveTransform(src, dst) # Matrix 얻어옴
    result = cv2.warpPerspective(src_img, matrix, (width, height)) # matrix대로 변환을 함
    cv2.imshow('result', result)

cv2.namedWindow('img') # img란 이름의 윈도우를 먼저 만들어두는 것. 여기에 마우스 이벤트를 처리하기 위한 핸들러 적용
cv2.setMouseCallback('img', mouse_handler)

cv2.imshow('img', src_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 30, in mouse_handler(event, x, y, flags, param)
#      28     show_result()
#      29     next_point = point_list[0] # 첫번째 클릭한 시점
# ---> 30 cv2.line(dst_img, prev_point, next_point, COLOR, THICKNESS, cv2.LINE_AA)
#      32 cv2.imshow('img', dst_img)
#
# UnboundLocalError: local variable 'prev_point' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 30, in mouse_handler(event, x, y, flags, param)
#      28     show_result()
#      29     next_point = point_list[0] # 첫번째 클릭한 시점
# ---> 30 cv2.line(dst_img, prev_point, next_point, COLOR, THICKNESS, cv2.LINE_AA)
#      32 cv2.imshow('img', dst_img)
#
# ...
